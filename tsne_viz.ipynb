# %%
# Code adopted from Kaggle example:
# https://www.kaggle.com/code/rcushen/topic-modelling-with-lsa-and-lda

import numpy as np
import pandas as pd
from IPython.display import display
from tqdm import tqdm
from collections import Counter
import ast

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import seaborn as sb

from sklearn.feature_extraction.text import CountVectorizer
from textblob import TextBlob
import scipy.stats as stats

from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.manifold import TSNE

from bokeh.plotting import figure, output_file, show
from bokeh.models import Label
from bokeh.io import output_notebook
output_notebook()

# %matplotlib inline
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1637">Loading BokehJS ...</span>
#     </div>

# %%
datafile = 'abcnews-date-text.csv'
raw_data = pd.read_csv(datafile, parse_dates=[0], infer_datetime_format=True)

reindexed_data = raw_data['headline_text']
reindexed_data.index = raw_data['publish_date']

raw_data.head()
# Out:
#   publish_date                                      headline_text
# 0   2003-02-19  aba decides against community broadcasting lic...
# 1   2003-02-19     act fire witnesses must be aware of defamation
# 2   2003-02-19     a g calls for infrastructure protection summit
# 3   2003-02-19           air nz staff in aust strike for pay rise
# 4   2003-02-19      air nz strike to affect australian travellers

# %%
# Define helper functions
def get_top_n_words(n_top_words, count_vectorizer, text_data):
    '''
    returns a tuple of the top n words in a sample and their 
    accompanying counts, given a CountVectorizer object and text sample
    '''
    vectorized_headlines = count_vectorizer.fit_transform(text_data.values)
    vectorized_total = np.sum(vectorized_headlines, axis=0)
    word_indices = np.flip(np.argsort(vectorized_total)[0,:], 1)
    word_values = np.flip(np.sort(vectorized_total)[0,:],1)
    
    word_vectors = np.zeros((n_top_words, vectorized_headlines.shape[1]))
    for i in range(n_top_words):
        word_vectors[i,word_indices[0,i]] = 1

    words = [word[0].encode('ascii').decode('utf-8') for 
             word in count_vectorizer.inverse_transform(word_vectors)]

    return (words, word_values[0,:n_top_words].tolist()[0])

# %%
count_vectorizer = CountVectorizer(stop_words='english')
words, word_values = get_top_n_words(n_top_words=15,
                                     count_vectorizer=count_vectorizer, 
                                     text_data=reindexed_data)

fig, ax = plt.subplots(figsize=(16,8))
ax.bar(range(len(words)), word_values);
ax.set_xticks(range(len(words)));
ax.set_xticklabels(words, rotation='vertical');
ax.set_title('Top words in headlines dataset (excluding stop words)');
ax.set_xlabel('Word');
ax.set_ylabel('Number of occurences');
plt.show()

# %%
# tagged_headlines = [TextBlob(reindexed_data[i]).pos_tags for i in range(reindexed_data.shape[0])]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 tagged_headlines = [TextBlob(reindexed_data[i]).pos_tags for i in range(reindexed_data.shape[0])]
#
# Cell In [7], line 1, in <listcomp>(.0)
# ----> 1 tagged_headlines = [TextBlob(reindexed_data[i]).pos_tags for i in range(reindexed_data.shape[0])]
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/textblob/decorators.py:24, in cached_property.__get__(self, obj, cls)
#      22 if obj is None:
#      23     return self
# ---> 24 value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25 return value
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/textblob/blob.py:499, in BaseBlob.pos_tags(self)
#     488 """Returns an list of tuples of the form (word, POS tag).
#     489
#     490 Example:
#    (...)
#     496 :rtype: list of tuples
#     497 """
#     498 if isinstance(self, TextBlob):
# --> 499     return [val for sublist in [s.pos_tags for s in self.sentences] for val in sublist]
#     500 else:
#     501     return [(Word(unicode(word), pos_tag=t), unicode(t))
#     502             for word, t in self.pos_tagger.tag(self)
#     503             if not PUNCTUATION_REGEX.match(unicode(t))]
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/textblob/blob.py:499, in <listcomp>(.0)
#     488 """Returns an list of tuples of the form (word, POS tag).
#     489
#     490 Example:
#    (...)
#     496 :rtype: list of tuples
#     497 """
#     498 if isinstance(self, TextBlob):
# --> 499     return [val for sublist in [s.pos_tags for s in self.sentences] for val in sublist]
#     500 else:
#     501     return [(Word(unicode(word), pos_tag=t), unicode(t))
#     502             for word, t in self.pos_tagger.tag(self)
#     503             if not PUNCTUATION_REGEX.match(unicode(t))]
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/textblob/decorators.py:24, in cached_property.__get__(self, obj, cls)
#      22 if obj is None:
#      23     return self
# ---> 24 value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25 return value
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/textblob/blob.py:502, in BaseBlob.pos_tags(self)
#     499     return [val for sublist in [s.pos_tags for s in self.sentences] for val in sublist]
#     500 else:
#     501     return [(Word(unicode(word), pos_tag=t), unicode(t))
# --> 502             for word, t in self.pos_tagger.tag(self)
#     503             if not PUNCTUATION_REGEX.match(unicode(t))]
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/textblob/decorators.py:35, in requires_nltk_corpus.<locals>.decorated(*args, **kwargs)
#      32 @wraps(func)
#      33 def decorated(*args, **kwargs):
#      34     try:
# ---> 35         return func(*args, **kwargs)
#      36     except LookupError as err:
#      37         print(err)
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/textblob/en/taggers.py:38, in NLTKTagger.tag(self, text)
#      35 if isinstance(text, textblob.compat.text_type):
#      36     text = tb.TextBlob(text)
# ---> 38 return nltk.tag.pos_tag(text.tokens)
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/textblob/decorators.py:24, in cached_property.__get__(self, obj, cls)
#      22 if obj is None:
#      23     return self
# ---> 24 value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25 return value
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/textblob/blob.py:410, in BaseBlob.tokens(self)
#     405 @cached_property
#     406 def tokens(self):
#     407     """Return a list of tokens, using this blob's tokenizer object
#     408     (defaults to :class:`WordTokenizer <textblob.tokenizers.WordTokenizer>`).
#     409     """
# --> 410     return WordList(self.tokenizer.tokenize(self.raw))
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/textblob/tokenizers.py:34, in WordTokenizer.tokenize(self, text, include_punc)
#      28 def tokenize(self, text, include_punc=True):
#      29     '''Return a list of word tokens.
#      30
#      31     :param text: string of text.
#      32     :param include_punc: (optional) whether to include punctuation as separate tokens. Default to True.
#      33     '''
# ---> 34     tokens = nltk.tokenize.word_tokenize(text)
#      35     if include_punc:
#      36         return tokens
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/tokenize/__init__.py:130, in word_tokenize(text, language, preserve_line)
#     115 """
#     116 Return a tokenized copy of *text*,
#     117 using NLTK's recommended word tokenizer
#    (...)
#     127 :type preserve_line: bool
#     128 """
#     129 sentences = [text] if preserve_line else sent_tokenize(text, language)
# --> 130 return [
#     131     token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132 ]
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/tokenize/__init__.py:131, in <listcomp>(.0)
#     115 """
#     116 Return a tokenized copy of *text*,
#     117 using NLTK's recommended word tokenizer
#    (...)
#     127 :type preserve_line: bool
#     128 """
#     129 sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130 return [
# --> 131     token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132 ]
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/tokenize/destructive.py:157, in NLTKWordTokenizer.tokenize(self, text, convert_parentheses, return_str)
#     149 if return_str:
#     150     warnings.warn(
#     151         "Parameter 'return_str' has been deprecated and should no "
#     152         "longer be used.",
#     153         category=DeprecationWarning,
#     154         stacklevel=2,
#     155     )
# --> 157 for regexp, substitution in self.STARTING_QUOTES:
#     158     text = regexp.sub(substitution, text)
#     160 for regexp, substitution in self.PUNCTUATION:
#
# KeyboardInterrupt:

# %%
# y = stats.norm.pdf(np.linspace(0,14,50), np.mean(word_counts), np.std(word_counts))

# fig, ax = plt.subplots(figsize=(18,8))
# ax.hist(word_counts, bins=range(1,14), density=True);
# ax.plot(np.linspace(0,14,50), y, 'r--', linewidth=1);
# ax.set_title('Headline word lengths');
# ax.set_xticks(range(1,14));
# ax.set_xlabel('Number of words');
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 y = stats.norm.pdf(np.linspace(0,14,50), np.mean(word_counts), np.std(word_counts))
#       3 fig, ax = plt.subplots(figsize=(18,8))
#       4 ax.hist(word_counts, bins=range(1,14), density=True);
#
# NameError: name 'word_counts' is not defined

# %%
# pos_sorted_types = sorted(pos_counts, key=pos_counts.__getitem__, reverse=True)
# pos_sorted_counts = sorted(pos_counts.values(), reverse=True)

# fig, ax = plt.subplots(figsize=(18,8))
# ax.bar(range(len(pos_counts)), pos_sorted_counts);
# ax.set_xticks(range(len(pos_counts)));
# ax.set_xticklabels(pos_sorted_types);
# ax.set_title('Part-of-Speech Tagging for Headlines Corpus');
# ax.set_xlabel('Type of Word');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 pos_sorted_types = sorted(pos_counts, key=pos_counts.__getitem__, reverse=True)
#       2 pos_sorted_counts = sorted(pos_counts.values(), reverse=True)
#       4 fig, ax = plt.subplots(figsize=(18,8))
#
# NameError: name 'pos_counts' is not defined

# %%
small_count_vectorizer = CountVectorizer(stop_words='english', max_features=40000)
small_text_sample = reindexed_data.sample(n=10000, random_state=0).values

print('Headline before vectorization: {}'.format(small_text_sample[123]))

small_document_term_matrix = small_count_vectorizer.fit_transform(small_text_sample)

print('Headline after vectorization: \n{}'.format(small_document_term_matrix[123]))
# Out:
# Headline before vectorization: leaders of womens group plan parliament march to
# Headline after vectorization:
#   (0, 8434)	1
#   (0, 6467)	1
#   (0, 12467)	1
#   (0, 5001)	1
#   (0, 8151)	1
#   (0, 6923)	1

# %% [markdown]
# # Latent Semantic Analysis (LSA)

# %%
# Define helper functions
def get_keys(topic_matrix):
    '''
    returns an integer list of predicted topic 
    categories for a given topic matrix
    '''
    keys = topic_matrix.argmax(axis=1).tolist()
    return keys

def keys_to_counts(keys):
    '''
    returns a tuple of topic categories and their 
    accompanying magnitudes for a given list of keys
    '''
    count_pairs = Counter(keys).items()
    categories = [pair[0] for pair in count_pairs]
    counts = [pair[1] for pair in count_pairs]
    return (categories, counts)

# %%
n_topics = 8

lsa_model = TruncatedSVD(n_components=n_topics)
lsa_topic_matrix = lsa_model.fit_transform(small_document_term_matrix)
lsa_keys = get_keys(lsa_topic_matrix)
lsa_categories, lsa_counts = keys_to_counts(lsa_keys)

# %%
# Define helper functions
def get_top_n_words(n, keys, document_term_matrix, count_vectorizer):
    '''
    returns a list of n_topic strings, where each string contains the n most common 
    words in a predicted category, in order
    '''
    top_word_indices = []
    for topic in range(n_topics):
        temp_vector_sum = 0
        for i in range(len(keys)):
            if keys[i] == topic:
                temp_vector_sum += document_term_matrix[i]
        temp_vector_sum = temp_vector_sum.toarray()
        top_n_word_indices = np.flip(np.argsort(temp_vector_sum)[0][-n:],0)
        top_word_indices.append(top_n_word_indices)   
    top_words = []
    for topic in top_word_indices:
        topic_words = []
        for index in topic:
            temp_word_vector = np.zeros((1,document_term_matrix.shape[1]))
            temp_word_vector[:,index] = 1
            the_word = count_vectorizer.inverse_transform(temp_word_vector)[0][0]
            topic_words.append(the_word.encode('ascii').decode('utf-8'))
        top_words.append(" ".join(topic_words))         
    return top_words

# %%
top_n_words_lsa = get_top_n_words(10, lsa_keys, small_document_term_matrix, small_count_vectorizer)

for i in range(len(top_n_words_lsa)):
    print("Topic {}: ".format(i+1), top_n_words_lsa[i])
# Out:
# Topic 1:  police death missing murder search woman adelaide probe man house
# Topic 2:  man charged guilty jailed sex murder pleads death child assault
# Topic 3:  new help year home indigenous deal laws chief old tasmanian
# Topic 4:  says health wa minister government sa power election workers iraq
# Topic 5:  govt nsw water qld rural national north coast nt school
# Topic 6:  australia interview day win world coronavirus south test wins cup
# Topic 7:  crash car dies killed hospital road injured fatal cup driver
# Topic 8:  council court australian plan face accused case high fight residents

# %%
top_3_words = get_top_n_words(3, lsa_keys, small_document_term_matrix, small_count_vectorizer)
labels = ['Topic {}: \n'.format(i) + top_3_words[i] for i in lsa_categories]

fig, ax = plt.subplots(figsize=(16,8))
ax.bar(lsa_categories, lsa_counts);
ax.set_xticks(lsa_categories);
ax.set_xticklabels(labels);
ax.set_ylabel('Number of headlines');
ax.set_title('LSA topic counts');
plt.show()

# %%
tsne_lsa_model = TSNE(n_components=2, perplexity=50, learning_rate=100, 
                        n_iter=2000, verbose=1, random_state=0, angle=0.75)
tsne_lsa_vectors = tsne_lsa_model.fit_transform(lsa_topic_matrix)
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.011s...
# [t-SNE] Computed neighbors for 10000 samples in 0.773s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.002617
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 75.391243
# [t-SNE] KL divergence after 2000 iterations: 1.293573

# %%
# Define helper functions
def get_mean_topic_vectors(keys, two_dim_vectors):
    '''
    returns a list of centroid vectors from each predicted topic category
    '''
    mean_topic_vectors = []
    for t in range(n_topics):
        articles_in_that_topic = []
        for i in range(len(keys)):
            if keys[i] == t:
                articles_in_that_topic.append(two_dim_vectors[i])    
        
        articles_in_that_topic = np.vstack(articles_in_that_topic)
        mean_article_in_that_topic = np.mean(articles_in_that_topic, axis=0)
        mean_topic_vectors.append(mean_article_in_that_topic)
    return mean_topic_vectors

# %%
colormap = np.array([
    "#1f77b4", "#aec7e8", "#ff7f0e", "#ffbb78", "#2ca02c",
    "#98df8a", "#d62728", "#ff9896", "#9467bd", "#c5b0d5",
    "#8c564b", "#c49c94", "#e377c2", "#f7b6d2", "#7f7f7f",
    "#c7c7c7", "#bcbd22", "#dbdb8d", "#17becf", "#9edae5" ])
colormap = colormap[:n_topics]

# %%
top_3_words_lsa = get_top_n_words(3, lsa_keys, small_document_term_matrix, small_count_vectorizer)
lsa_mean_topic_vectors = get_mean_topic_vectors(lsa_keys, tsne_lsa_vectors)

plot = figure(title="t-SNE Clustering of {} LSA Topics".format(n_topics), width=700, height=700)
plot.scatter(x=tsne_lsa_vectors[:,0], y=tsne_lsa_vectors[:,1], color=colormap[lsa_keys])

for t in range(n_topics):
    label = Label(x=lsa_mean_topic_vectors[t][0], y=lsa_mean_topic_vectors[t][1], 
                  text=top_3_words_lsa[t], text_color=colormap[t])
    plot.add_layout(label)


show(plot)
# Out:
#   <div id="9dc82c39-68f6-4400-b2c9-cbdd45e28d52" data-root-id="p2252" style="display: contents;"></div>

# %% [markdown]
# # Latent Dirichlet Allocation (LDA)

# %%
lda_model = LatentDirichletAllocation(n_components=n_topics, learning_method='online', 
                                          random_state=0, verbose=0)
lda_topic_matrix = lda_model.fit_transform(small_document_term_matrix)

# %%
lda_keys = get_keys(lda_topic_matrix)
lda_categories, lda_counts = keys_to_counts(lda_keys)

# %%
top_n_words_lda = get_top_n_words(10, lda_keys, small_document_term_matrix, small_count_vectorizer)

for i in range(len(top_n_words_lda)):
    print("Topic {}: ".format(i+1), top_n_words_lda[i])

# %%
top_3_words = get_top_n_words(3, lda_keys, small_document_term_matrix, small_count_vectorizer)
labels = ['Topic {}: \n'.format(i) + top_3_words[i] for i in lda_categories]

fig, ax = plt.subplots(figsize=(16,8))
ax.bar(lda_categories, lda_counts);
ax.set_xticks(lda_categories);
ax.set_xticklabels(labels);
ax.set_title('LDA topic counts');
ax.set_ylabel('Number of headlines');

# %%
tsne_lda_model = TSNE(n_components=2, perplexity=50, learning_rate=100, 
                        n_iter=2000, verbose=1, random_state=0, angle=0.75)
tsne_lda_vectors = tsne_lda_model.fit_transform(lda_topic_matrix)

# %%
top_3_words_lda = get_top_n_words(3, lda_keys, small_document_term_matrix, small_count_vectorizer)
lda_mean_topic_vectors = get_mean_topic_vectors(lda_keys, tsne_lda_vectors)

plot = figure(title="t-SNE Clustering of {} LDA Topics".format(n_topics), width=700, height=700)
plot.scatter(x=tsne_lda_vectors[:,0], y=tsne_lda_vectors[:,1], color=colormap[lda_keys])

for t in range(n_topics):
    label = Label(x=lda_mean_topic_vectors[t][0], y=lda_mean_topic_vectors[t][1], 
                  text=top_3_words_lda[t], text_color=colormap[t])
    plot.add_layout(label)

show(plot)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9a809945-6c8f-453a-8cfa-9f77d6648913' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
